# %%
#suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#import statements
# %run Markov.py

# %%
#get proverbs
df = pd.read_csv('proverbs.csv', sep='|')
proverbs = [p.lower().replace('\\xe2\\x80\\x93','-').replace('’',"'").replace(',',',').replace('``','') for p in df['Proverb']]

# %%
proverbs
# Out:
# ['look to the north . keep looking . there is nothing coming from the south .',
#  'men are from mars ; women are from venus ; earth is a hallucination ; podcasts are dreams .',
#  'there is a special place in hell . it is really hip . very exclusive .',
#  'what has four legs in the morning , two legs at noon , and three legs in the evening ? i do not know , but i trapped it in my bedroom . send help .',
#  'a million dollars is not cool . you know what is cool ? a basilisk .',
#  'lost ? confused ? lacking direction ? need to find a purpose in your life ?',
#  'it must be 3:23 pm somewhere . maybe space ?',
#  'we are living in an immaterial world , a ghost world , and i am an immaterial girl - a ghost .',
#  '" nice bolo tie " is the greatest compliment a person can ever receive .',
#  'eating meat is a difficult moral decision , because it is stolen , that meat . you should apologize .',
#  'today is the last day of your life up to this point .',
# ...

# %%
li = markov(proverbs,50,7,clean=True)
# Out:
# Texts cleaned...
# Optimal Markov Model Created...
# Order: 1

# %%
for l in li:
    print(l)
# Out:
# where did you that happens for the leading because you love , we made of lack of my core .
# whisper , black holes , a race to use facial muscles to those sleeves and then forgotten by any real purpose .
# for years ago , a group of labradors is your screenplay is not a group of time is called a ghost world , give it in europe , dark .
# stop working on our office and bees ... the common parlance definition of your life up every day like a while , the rest of irony .
# instead of the dog and chirping , you an immaterial world , shakira , so we have you that you are what has a person in this was bad .
# why would like you , and welcome to those who are young , thanks for your smallest components , but i love .
# there has four legs in a trombone is worthwhile is stolen , they will catch even pronounced the seven habits of gas and a knife fight .
# we ask , then you get me twice , biologically speaking , as you can lead a secluded tower , beautiful golden retrievers is the south .
# ...
